# %%
import pandas as pd

# %%
path = "./2020_arrest_motivation.csv"
df = pd.read_csv(path)
df
# Out:
#     Number  Precinct  Gender            Race  Age            Bias-Motivation
# 0        1         5    MALE  BLACK HISPANIC   38                 ANTI-ASIAN
# 1        2         5    MALE           WHITE   32                ANTI-JEWISH
# 2        3         6    MALE           BLACK   38                 ANTI-ASIAN
# 3        4         6    MALE           BLACK   37  ANTI-MALE HOMOSEXUAL(GAY)
# 4        5         7  FEMALE           BLACK   50                 ANTI-ASIAN
# ..     ...       ...     ...             ...  ...                        ...
# 88      89       120  FEMALE  WHITE HISPANIC   70                 ANTI-ASIAN
# 89      90       120  FEMALE  WHITE HISPANIC   70                 ANTI-BLACK
# 90      91       120  FEMALE  WHITE HISPANIC   70  ANTI-MALE HOMOSEXUAL(GAY)
# 91      92       120  FEMALE  WHITE HISPANIC   70                 ANTI-WHITE
# 92      93       120  FEMALE  WHITE HISPANIC   70                 ANTI-WHITE
#
# [93 rows x 6 columns]
