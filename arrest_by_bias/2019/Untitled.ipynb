# %%
import pandas as pd

# %%
path = "./2019_arrest_motivation.csv"
df = pd.read_csv(path, skiprows=5)
df
# Out:
#      Number  Precinct  Gender   Race  Age             Bias-Motivation  \
# 0         1       1.0  Female  White   64       Anti-Islamic (Muslim)
# 1         2       5.0  Female  White   49               Anti-Hispanic
# 2         3       NaN    Male  White   44       Anti-Islamic (Muslim)
# 3         4       NaN    Male  Black   41                  Anti-White
# 4         5       6.0    Male  Black   21                 Anti-Jewish
# ..      ...       ...     ...    ...  ...                         ...
# 128     129       NaN    Male  White   12                 Anti-Jewish
# 129     130     113.0    Male  Asian   61                  Anti-Black
# 130     131     114.0    Male  Asian   24                 Anti-Jewish
# 131     132     115.0    Male  White   28  Anti-male homosexual (Gay)
# 132     133       NaN    Male  White   28  Anti-male homosexual (Gay)
#
#      Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10
# ...
