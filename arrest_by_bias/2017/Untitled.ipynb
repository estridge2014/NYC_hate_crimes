# %%
import pandas as pd 
import numpy as np

# %%
path = "./2017_arrest_motivation.csv"
df = pd.read_csv(path, skiprows=5)
df
# Out:
#      Precinct  Number  Gender   Race   Age      Bias Motivation
# 0         1.0     1.0    Male  White  40.0  Anit-Other Religion
# 1         NaN     2.0    Male  Black  29.0           Anti-White
# 2         6.0     3.0    Male  White  48.0           Anti-Asian
# 3         NaN     4.0    Male  White  32.0            Anti-LGBT
# 4         NaN     5.0    Male  White  59.0           Anti-Black
# ..        ...     ...     ...    ...   ...                  ...
# 131       NaN   132.0    Male  Black  20.0            Anti-LGBT
# 132     121.0   133.0    Male  White  57.0        Anti-Hispanic
# 133     122.0   134.0  Female  White  44.0           Anti-Black
# 134     123.0   135.0    Male  White  37.0          Anti-Jewish
# 135       NaN     NaN     NaN    NaN   NaN                  NaN
#
# [136 rows x 6 columns]

# %%
df.dtypes
# Out:
# Precinct           float64
# Number             float64
# Gender              object
# Race                object
#  Age               float64
# Bias Motivation     object
# dtype: object

# %%
# Change data type from float64 to int to remove the decimal points from precinct, number, and age columns
# using apply method
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-807da66d1b83> in <module>
#       1 # Change data type from float64 to int to remove the decimal points from precinct, number, and age columns
#       2 # using apply method
# ----> 3 df[[' Age']] = df[['Age']].apply(pd.to_numeric)
#
# ~/opt/anaconda3/envs/pythondata/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3459             if is_iterator(key):
#    3460                 key = list(key)
# -> 3461             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3462
#    3463         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/envs/pythondata/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# ...

# %%
#drop last row
last_row = len(df) - 1
df = df.drop(df.index[last_row])
df
# Out:
#      Precinct  Number  Gender   Race   Age      Bias Motivation
# 0         1.0     1.0    Male  White  40.0  Anit-Other Religion
# 1         NaN     2.0    Male  Black  29.0           Anti-White
# 2         6.0     3.0    Male  White  48.0           Anti-Asian
# 3         NaN     4.0    Male  White  32.0            Anti-LGBT
# 4         NaN     5.0    Male  White  59.0           Anti-Black
# ..        ...     ...     ...    ...   ...                  ...
# 130       NaN   131.0  Female  White  38.0            Anti-LGBT
# 131       NaN   132.0    Male  Black  20.0            Anti-LGBT
# 132     121.0   133.0    Male  White  57.0        Anti-Hispanic
# 133     122.0   134.0  Female  White  44.0           Anti-Black
# 134     123.0   135.0    Male  White  37.0          Anti-Jewish
#
# [135 rows x 6 columns]
