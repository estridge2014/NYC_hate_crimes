# %%
import pandas as pd

# %%
path_q1 = "./2021_q1_arrest_motivation.csv"
df_q1 = pd.read_csv(path_q1, skiprows=5)
df_q1
# Out:
#     Number  Precinct  Gender                      Race  Age  \
# 0        1        14    MALE                     WHITE   40
# 1        2        84    MALE            WHITE HISPANIC   25
# 2        3        90    MALE                     BLACK   29
# 3        4        90    MALE                     BLACK   29
# 4        5        90    MALE                     BLACK   29
# 5        6        90    MALE                     BLACK   29
# 6        7        90    MALE                     BLACK   29
# 7        8        90    MALE                     BLACK   29
# 8        9        83    MALE                     BLACK   29
# 9       10        90    MALE                     BLACK   29
# 10      11        90    MALE                     BLACK   29
# 11      12        40    MALE                     BLACK   18
# 12      13         7    MALE                     BLACK   15
# 13      14        13    MALE  ASIAN / PACIFIC ISLANDER   25
# 14      15        75    MALE                     WHITE   30
# ...

# %%
path_q2 = "./2021_q2_arrest_motivation.csv"
df_q2 = pd.read_csv(path_q2, skiprows=5)
df_q2
# Out:
#     Number  Precinct  Gender                      Race  Age  \
# 0        1       5.0  FEMALE                     BLACK   50
# 1        2       6.0    MALE            WHITE HISPANIC   24
# 2        3       7.0  FEMALE                     BLACK   14
# 3        4       NaN  FEMALE                     BLACK   29
# 4        5       NaN    MALE            BLACK HISPANIC   31
# ..     ...       ...     ...                       ...  ...
# 77      78     120.0  FEMALE                     BLACK   25
# 78      79       NaN    MALE                     WHITE   52
# 79      80     122.0    MALE  ASIAN / PACIFIC ISLANDER   18
# 80      81       NaN    MALE  ASIAN / PACIFIC ISLANDER   19
# 81      82       NaN    MALE  ASIAN / PACIFIC ISLANDER   22
#
#               Bias-Motivation
# 0                  ANTI-ASIAN
# 1   ANTI-MALE HOMOSEXUAL(GAY)
# 2                  ANTI-ASIAN
# 3                  ANTI-ASIAN
# 4                  ANTI-ASIAN
# ..                        ...
# ...

# %%
path_q3 = "./2021_q3_arrest_motivation.csv"
df_q3 = pd.read_csv(path_q3, skiprows=5)
df_q3
# Out:
#     Number  Precinct  Gender                           Race  Age  \
# 0        1         7    MALE                          BLACK   21
# 1        2       107  FEMALE                          BLACK   25
# 2        3       107  FEMALE                          BLACK   25
# 3        4       107  FEMALE                          BLACK   25
# 4        5       107  FEMALE                          BLACK   25
# 5        6         7  FEMALE                          BLACK   31
# 6        7        14    MALE                          BLACK   35
# 7        8        14    MALE                          WHITE   36
# 8        9        84    MALE                 WHITE HISPANIC   38
# 9       10       107    MALE                 WHITE HISPANIC   39
# 10      11         7    MALE                          BLACK   47
# 11      12        13    MALE                          WHITE   47
# 12      13        61    MALE                          BLACK   52
# ...
