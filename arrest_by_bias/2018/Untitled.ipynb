# %%
import pandas as pd
import os
import re

# %%
path = "/Users/savannahestridge/Desktop/NYC_hate_crimes/arrest_by_bias/2018/2018_arrest_motivation.csv"

df = pd.read_csv(path, skiprows=5)
df
# Out:
#      Number  Precinct  Gender   Race  Age             Bias-Motivation  \
# 0         1       1.0    Male  Black   24                 Anti-Jewish
# 1         2       NaN    Male  Black   24                 Anti-Jewish
# 2         3       NaN    Male  Black   24                 Anti-Jewish
# 3         4       NaN    Male  Black   24                 Anti-Jewish
# 4         5       NaN  Female  Black   37                  Anti-White
# ..      ...       ...     ...    ...  ...                         ...
# 145     146       NaN    Male  Asian   57  Anti-male homosexual (Gay)
# 146     147     115.0    Male  White   55                  Anti-Black
# 147     148     120.0    Male  Black   14                  Anti-White
# 148     149     122.0    Male  White   33                  Anti-Black
# 149     150       NaN    Male  White   26                  Anti-Black
#
#      Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10
# ...

# %%
df = df[['Number', 'Precinct', 'Gender', 'Race', 'Age', 'Bias-Motivation']]
df
# Out:
#      Number  Precinct  Gender   Race  Age             Bias-Motivation
# 0         1       1.0    Male  Black   24                 Anti-Jewish
# 1         2       NaN    Male  Black   24                 Anti-Jewish
# 2         3       NaN    Male  Black   24                 Anti-Jewish
# 3         4       NaN    Male  Black   24                 Anti-Jewish
# 4         5       NaN  Female  Black   37                  Anti-White
# ..      ...       ...     ...    ...  ...                         ...
# 145     146       NaN    Male  Asian   57  Anti-male homosexual (Gay)
# 146     147     115.0    Male  White   55                  Anti-Black
# 147     148     120.0    Male  Black   14                  Anti-White
# 148     149     122.0    Male  White   33                  Anti-Black
# 149     150       NaN    Male  White   26                  Anti-Black
#
# [150 rows x 6 columns]

# %%
df.dtypes
# Out:
# Number               int64
# Precinct           float64
# Gender              object
# Race                object
# Age                  int64
# Bias-Motivation     object
# dtype: object

# %%
print(df1.head(20))
# Out:
#     Number  Precinct  Gender   Race  Age             Bias-Motivation
# 0        1       1.0    Male  Black   24                 Anti-Jewish
# 1        2       NaN    Male  Black   24                 Anti-Jewish
# 2        3       NaN    Male  Black   24                 Anti-Jewish
# 3        4       NaN    Male  Black   24                 Anti-Jewish
# 4        5       NaN  Female  Black   37                  Anti-White
# 5        6       NaN    Male  White   35                 Anti-Jewish
# 6        7       NaN    Male  White   35                 Anti-Jewish
# 7        8       5.0    Male  Black   29  Anti-male homosexual (Gay)
# 8        9       NaN    Male  White   57                  Anti-Black
# 9       10       6.0  Female  White   58            Anti-Transgender
# 10      11       NaN    Male  White   44  Anti-male homosexual (Gay)
# 11      12       NaN    Male  White   47       Anti-Islamic (Muslim)
# 12      13       NaN    Male  White   35                 Anti-Jewish
# ...

# %%
#remove decimal points from Precinct column

df['Precinct'] = df['Precinct'].astype(int).apply(lambda x: x.replace('.0',''))
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# <ipython-input-9-9235d7a87332> in <module>
#       1 #remove decimal points from Precinct column
#       2
# ----> 3 df['Precinct'] = df['Precinct'].astype(int).apply(lambda x: x.replace('.0',''))
#
# ~/opt/anaconda3/envs/pythondata/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5804         else:
#    5805             # else, only a single dtype is given
# -> 5806             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5807             return self._constructor(new_data).__finalize__(self, method="astype")
#    5808
#
# ~/opt/anaconda3/envs/pythondata/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     412
#     413     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...
